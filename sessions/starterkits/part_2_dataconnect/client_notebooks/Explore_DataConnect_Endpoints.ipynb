# %% [markdown]
# # Data Connect
# **Find the detailed GA4GH Data Connect Specification [here](https://github.com/ga4gh-discovery/data-connect).**

# %%
import requests
import json

dc_port = "4800"
dc_base_url = "http://localhost:{}".format(dc_port)


service_info_path = "/service-info"
tables_path = "/tables"
table_info_path = "/table/{}/info"
table_data_path = "/table/{}/data"
search_path = "/search"

def pretty_print_json(response):
    print(json.dumps(response.json(), indent=4))

# %% [markdown]
# ## 🔷 GET `/service-info`
# **Retrieve information about this service**

# %%
dc_service_info_resp = requests.request("GET", dc_base_url+service_info_path)
pretty_print_json(dc_service_info_resp)
# Out:
# {
#     "id": "org.ga4gh.starterkit.dataconnect",
#     "name": "GA4GH Starter Kit Data Connect Service",
#     "description": "Starter Kit implementation of the  Data Connect API specification. Gives researchers access to the data  model of given datasets/tables, and enables them to perform search  queries on the datasets using the model.",
#     "contactUrl": "mailto:info@ga4gh.org",
#     "documentationUrl": "https://github.com/ga4gh/ga4gh-starter-kit-data-connect",
#     "createdAt": "2022-04-27T09:00:00Z",
#     "updatedAt": "2022-04-27T09:00:00Z",
#     "environment": "test",
#     "version": "0.1.0",
#     "type": {
#         "group": "org.ga4gh",
#         "artifact": "data-connect",
#         "version": "1.0.0"
#     },
#     "organization": {
#         "name": "Global Alliance for Genomics and Health",
#         "url": "https://ga4gh.org"
#     }
# }

# %% [markdown]
# ## 🔷 List the tables
# **Returns a list of all table names**

# %%
dc_list_tables_resp = requests.request("GET", dc_base_url+tables_path)
pretty_print_json(dc_list_tables_resp)
# Out:
# {
#     "tables": [
#         {
#             "name": "one_thousand_genomes_sample",
#             "description": "Table / directory containing JSON files for one thousand genomes sample from https://www.internationalgenome.org",
#             "data_model": {
#                 "$ref": "http://localhost:4500/table/one_thousand_genomes_sample/info"
#             }
#         },
#         {
#             "name": "phenopacket_v1",
#             "description": "Table / directory containing JSON files for phenopackets",
#             "data_model": {
#                 "$ref": "http://localhost:4500/table/phenopacket_v1/info"
#             }
#         }
#     ]
# }

# %% [markdown]
# ## 🔷 GET table information of the specificied table
# **Returns information about the specified table**

# %%
table_name = "one_thousand_genomes_sample"
dc_table_info_resp = requests.request("GET", dc_base_url+table_info_path.format(table_name))
pretty_print_json(dc_table_info_resp)
# Out:
# {
#     "name": "one_thousand_genomes_sample",
#     "description": "Table / directory containing JSON files for one thousand genomes sample from https://www.internationalgenome.org",
#     "data_model": {
#         "$id": "/table/one_thousand_genomes_sample/info",
#         "$schema": "http://json-schema.org/draft-07/schema#",
#         "description": "one thousand genomes sample JSON data model",
#         "properties": {
#             "sample_name": {
#                 "type": "string",
#                 "description": "An identifier specific for this genome sample"
#             },
#             "sex": {
#                 "type": "string",
#                 "enum": [
#                     "male",
#                     "female"
#                 ]
#             },
#             "biosample_id": {
#                 "type": "string",
#                 "description": "bio sample identifier"
#             },
#             "population_code": {
#                 "type": "string",
#                 "enum": [
#                     "ITU",
#                     "ASW",
#                     "JPT",
#                     "MSL",
#                     "CHS",
#                     "CDX",
#                     "YRI",
#                     "ACB",
#                     "MXL",
#                     "PUR",
#                     "FIN",
#                     "GWD",
#                     "LWK",
#                     "GIH",
#                     "CLM",
#                     "TSI",
#                     "PEL",
#                     "PJL",
#                     "GBR",
#                     "CHB",
#                     "BEB",
#                     "ESN",
#                     "KHV",
#                     "CEU",
#                     "IBS",
#                     "STU"
#                 ]
#             },
#             "population_name": {
#                 "type": "string",
#                 "enum": [
#                     "Bengali,Bengali",
#                     "African Ancestry SW",
#                     "Punjabi",
#                     "Dai Chinese",
#                     "Gambian Mandinka",
#                     "Yoruba",
#                     "British",
#                     "Japanese",
#                     "Iberian",
#                     "African Caribbean",
#                     "Mende",
#                     "Southern Han Chinese",
#                     "Han Chinese",
#                     "Luhya",
#                     "Kinh,Kinh Vietnamese",
#                     "Toscani",
#                     "Luhya,Luhya",
#                     "Kinh Vietnamese",
#                     "Tamil",
#                     "Gujarati",
#                     "Bengali",
#                     "Finnish",
#                     "CEPH",
#                     "Telugu",
#                     "Peruvian",
#                     "Esan",
#                     "Colombian",
#                     "Punjabi,Punjabi",
#                     "Puerto Rican",
#                     "Mexican Ancestry"
#                 ]
#             },
#             "superpopulation_code": {
#                 "type": "string",
#                 "enum": [
#                     "AMR",
#                     "EAS",
#                     "EUR",
#                     "SAS",
#                     "AFR"
#                 ]
#             },
#             "superpopulation_name": {
#                 "type": "string",
#                 "enum": [
#                     "East Asian Ancestry",
#                     "European Ancestry",
#                     "African Ancestry",
#                     "American Ancestry",
#                     "East Asia (SGDP),East Asian Ancestry",
#                     "South Asian Ancestry",
#                     "South Asia (SGDP),South Asian Ancestry",
#                     "African Ancestry,Africa (SGDP)"
#                 ]
#             },
#             "population_elastic_id": {
#                 "type": "string"
#             },
#             "data_collections": {
#                 "type": "string"
#             },
#             "cram_drs_uri": {
#                 "type": "string",
#                 "description": "drs uri pointing to the cram file"
#             },
#             "crai_drs_uri": {
#                 "type": "string",
#                 "description": "drs uri pointing to the crai file"
#             },
#             "bundle_drs_uri": {
#                 "type": "string",
#                 "description": "drs uri pointing to the bundle file"
#             }
#         }
#     }
# }

# %% [markdown]
# ## 🔷 GET table data of the specified table
# **Returns all the data in the specified table**

# %%
table_name = "one_thousand_genomes_sample"
dc_table_data_resp = requests.request("GET", dc_base_url+table_data_path.format(table_name))
pretty_print_json(dc_table_data_resp)
# Out:
# {
#     "data_model": {
#         "$id": "/table/one_thousand_genomes_sample/info",
#         "$schema": "http://json-schema.org/draft-07/schema#",
#         "description": "one thousand genomes sample JSON data model",
#         "properties": {
#             "sample_name": {
#                 "type": "string",
#                 "description": "An identifier specific for this genome sample"
#             },
#             "sex": {
#                 "type": "string",
#                 "enum": [
#                     "male",
#                     "female"
#                 ]
#             },
#             "biosample_id": {
#                 "type": "string",
#                 "description": "bio sample identifier"
#             },
#             "population_code": {
#                 "type": "string",
#                 "enum": [
#                     "ITU",
#                     "ASW",
#                     "JPT",
#                     "MSL",
#                     "CHS",
#                     "CDX",
#                     "YRI",
#                     "ACB",
#                     "MXL",
#                     "PUR",
#                     "FIN",
#                     "GWD",
#                     "LWK",
#                     "GIH",
#                     "CLM",
#                     "TSI",
#                     "PEL",
#                     "PJL",
#                     "GBR",
#                     "CHB",
#                     "BEB",
#                     "ESN",
#                     "KHV",
#                     "CEU",
#                     "IBS",
#                     "STU"
#                 ]
#             },
#             "population_name": {
#                 "type": "string",
#                 "enum": [
#                     "Bengali,Bengali",
#                     "African Ancestry SW",
#                     "Punjabi",
#                     "Dai Chinese",
#                     "Gambian Mandinka",
#                     "Yoruba",
#                     "British",
#                     "Japanese",
#                     "Iberian",
#                     "African Caribbean",
#                     "Mende",
#                     "Southern Han Chinese",
#                     "Han Chinese",
#                     "Luhya",
#                     "Kinh,Kinh Vietnamese",
#                     "Toscani",
#                     "Luhya,Luhya",
#                     "Kinh Vietnamese",
#                     "Tamil",
#                     "Gujarati",
#                     "Bengali",
#                     "Finnish",
#                     "CEPH",
#                     "Telugu",
#                     "Peruvian",
#                     "Esan",
#                     "Colombian",
#                     "Punjabi,Punjabi",
#                     "Puerto Rican",
#                     "Mexican Ancestry"
#                 ]
#             },
#             "superpopulation_code": {
#                 "type": "string",
#                 "enum": [
#                     "AMR",
#                     "EAS",
#                     "EUR",
#                     "SAS",
#                     "AFR"
#                 ]
#             },
#             "superpopulation_name": {
#                 "type": "string",
#                 "enum": [
#                     "East Asian Ancestry",
#                     "European Ancestry",
#                     "African Ancestry",
#                     "American Ancestry",
#                     "East Asia (SGDP),East Asian Ancestry",
#                     "South Asian Ancestry",
#                     "South Asia (SGDP),South Asian Ancestry",
#                     "African Ancestry,Africa (SGDP)"
#                 ]
#             },
#             "population_elastic_id": {
#                 "type": "string"
#             },
#             "data_collections": {
#                 "type": "string"
#             },
#             "cram_drs_uri": {
#                 "type": "string",
#                 "description": "drs uri pointing to the cram file"
#             },
#             "crai_drs_uri": {
#                 "type": "string",
#                 "description": "drs uri pointing to the crai file"
#             },
#             "bundle_drs_uri": {
#                 "type": "string",
#                 "description": "drs uri pointing to the bundle file"
#             }
#         }
#     },
#     "data": [
#         {
#             "sample_name": "HG01965",
#             "sex": "female",
#             "biosample_id": "SAME1839145",
#             "population_code": "PEL",
#             "population_name": "Peruvian",
#             "superpopulation_code": "AMR",
#             "superpopulation_name": "American Ancestry",
#             "population_elastic_id": "PEL",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release",
#             "cram_drs_uri": "drs://localhost:5000/05d0d8d45474c511d877993bd107b6bc",
#             "crai_drs_uri": "drs://localhost:5000/96c20b13a0515fcbc746b411df9f702b",
#             "bundle_drs_uri": "drs://localhost:5000/d670123e4f2ef711609a5713ce807aac"
#         },
#         {
#             "sample_name": "HG01577",
#             "sex": "male",
#             "biosample_id": "SAME124349",
#             "population_code": "PEL",
#             "population_name": "Peruvian",
#             "superpopulation_code": "AMR",
#             "superpopulation_name": "American Ancestry",
#             "population_elastic_id": "PEL",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release",
#             "cram_drs_uri": "drs://localhost:5000/0d2eff96559aa38bc3afe75b37ce13d4",
#             "crai_drs_uri": "drs://localhost:5000/8b839fcc7713f84af703a6d8cd9bb820",
#             "bundle_drs_uri": "drs://localhost:5000/fe9b74ab101054595edb1117b672233e"
#         },
#         {
#             "sample_name": "NA19625",
#             "sex": "female",
#             "biosample_id": "SAME123655",
#             "population_code": "ASW",
#             "population_name": "African Ancestry SW",
#             "superpopulation_code": "AFR",
#             "superpopulation_name": "African Ancestry",
#             "population_elastic_id": "ASW",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release,1000 Genomes phase 1 release",
#             "cram_drs_uri": "drs://localhost:5000/9692fe49ee764858c2050dec8c5f085e",
#             "crai_drs_uri": "drs://localhost:5000/c005f03509fc847ab81d380c08f4e65f",
#             "bundle_drs_uri": "drs://localhost:5000/bc6fd72c7397201eeb376e1d7f5f9d04"
#         },
#         {
#             "sample_name": "HG03823",
#             "sex": "female",
#             "biosample_id": "SAME1839456",
#             "population_code": "BEB",
#             "population_name": "Bengali",
#             "superpopulation_code": "SAS",
#             "superpopulation_name": "South Asian Ancestry",
#             "population_elastic_id": "BEB",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release",
#             "cram_drs_uri": "drs://localhost:5000/5aac2d73889876f19728790987c9f22f",
#             "crai_drs_uri": "drs://localhost:5000/832cba1ebb9a238a90cc89a5da2a1180",
#             "bundle_drs_uri": "drs://localhost:5000/46bde75991a50c7c3c84e0a4f6428a3c"
#         },
#         {
#             "sample_name": "NA20756",
#             "sex": "female",
#             "biosample_id": "SAME124175",
#             "population_code": "TSI",
#             "population_name": "Toscani",
#             "superpopulation_code": "EUR",
#             "superpopulation_name": "European Ancestry",
#             "population_elastic_id": "TSI",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release,1000 Genomes phase 1 release,Geuvadis",
#             "cram_drs_uri": "drs://localhost:5000/7fb5caa8ecd82e3fb519722c31f52363",
#             "crai_drs_uri": "drs://localhost:5000/d991d19ffc688b41f371a4230bdfe073",
#             "bundle_drs_uri": "drs://localhost:5000/942ab288d0de015101bb454585755c9a"
#         },
#         {
#             "sample_name": "NA18633",
#             "sex": "male",
#             "biosample_id": "SAME124704",
#             "population_code": "CHB",
#             "population_name": "Han Chinese",
#             "superpopulation_code": "EAS",
#             "superpopulation_name": "East Asian Ancestry",
#             "population_elastic_id": "CHB",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release,1000 Genomes phase 1 release,90 Han Chinese high coverage genomes",
#             "cram_drs_uri": "drs://localhost:5000/0a9f0c4eeb7af0b6ed68818bef8eeed6",
#             "crai_drs_uri": "drs://localhost:5000/fc874aaf8ca1ddb3d07f7a93dc7f3ee7",
#             "bundle_drs_uri": "drs://localhost:5000/f9bfdfef4066fa94bc10a14ac83e71ae"
#         },
#         {
#             "sample_name": "HG00740",
#             "sex": "female",
#             "biosample_id": "SAME124834",
#             "population_code": "PUR",
#             "population_name": "Puerto Rican",
#             "superpopulation_code": "AMR",
#             "superpopulation_name": "American Ancestry",
#             "population_elastic_id": "PUR",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release,1000 Genomes phase 1 release",
#             "cram_drs_uri": "drs://localhost:5000/28ffe6386b78fffb7cd0a7b2d0a79846",
#             "crai_drs_uri": "drs://localhost:5000/20d0bc8c7790bffb83c4400f0c615c52",
#             "bundle_drs_uri": "drs://localhost:5000/0c79342b27f3c760741db49c8d7a4e10"
#         },
#         {
#             "sample_name": "NA19090",
#             "sex": "female",
#             "biosample_id": "SAME123175",
#             "population_code": "JPT",
#             "population_name": "Japanese",
#             "superpopulation_code": "EAS",
#             "superpopulation_name": "East Asian Ancestry",
#             "population_elastic_id": "JPT",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release",
#             "cram_drs_uri": "drs://localhost:5000/14d1a3404871cd5f22e20ae685f47f06",
#             "crai_drs_uri": "drs://localhost:5000/a2ab38bf561f14b6654e2f3d341e21cb",
#             "bundle_drs_uri": "drs://localhost:5000/af9b08cfeb677330a8ba439c051de543"
#         },
#         {
#             "sample_name": "HG02600",
#             "sex": "male",
#             "biosample_id": "SAME1840302",
#             "population_code": "PJL",
#             "population_name": "Punjabi",
#             "superpopulation_code": "SAS",
#             "superpopulation_name": "South Asian Ancestry",
#             "population_elastic_id": "PJL",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release",
#             "cram_drs_uri": "drs://localhost:5000/abba3970f13e91c04f0ffc25eebc6e70",
#             "crai_drs_uri": "drs://localhost:5000/9f1f9631eb4329a64a84e7145042ad2d",
#             "bundle_drs_uri": "drs://localhost:5000/1f3d6d0a090cf770f748f744cf89e8c3"
#         },
#         {
#             "sample_name": "HG03731",
#             "sex": "female",
#             "biosample_id": "SAME1839372",
#             "population_code": "ITU",
#             "population_name": "Telugu",
#             "superpopulation_code": "SAS",
#             "superpopulation_name": "South Asian Ancestry",
#             "population_elastic_id": "ITU",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release",
#             "cram_drs_uri": "drs://localhost:5000/470ed7d9c2110cc7e8025c99ff2c00d9",
#             "crai_drs_uri": "drs://localhost:5000/44dc23e6ddb1aa3eb8f0b1531f91d351",
#             "bundle_drs_uri": "drs://localhost:5000/5e23550806e6e0306281049baa9d3436"
#         },
#         {
#             "sample_name": "HG01668",
#             "sex": "female",
#             "biosample_id": "SAME123111",
#             "population_code": "IBS",
#             "population_name": "Iberian",
#             "superpopulation_code": "EUR",
#             "superpopulation_name": "European Ancestry",
#             "population_elastic_id": "IBS",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release",
#             "cram_drs_uri": "drs://localhost:5000/0a5c27cbb252ad9762c5c4a8eb2e219d",
#             "crai_drs_uri": "drs://localhost:5000/c783b2630fdec50e22f51eb7748edbbf",
#             "bundle_drs_uri": "drs://localhost:5000/90d72ac8c2d6393648f49e74558f9633"
#         },
#         {
#             "sample_name": "HG01602",
#             "sex": "female",
#             "biosample_id": "SAME123454",
#             "population_code": "IBS",
#             "population_name": "Iberian",
#             "superpopulation_code": "EUR",
#             "superpopulation_name": "European Ancestry",
#             "population_elastic_id": "IBS",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release",
#             "cram_drs_uri": "drs://localhost:5000/f61bda143a84326f32edfc1707577568",
#             "crai_drs_uri": "drs://localhost:5000/7ae9bc9de194dedcf9ab8d624a1bda0a",
#             "bundle_drs_uri": "drs://localhost:5000/661f0fd87983e496a73c88f1d71e84f7"
#         },
#         {
#             "sample_name": "NA20896",
#             "sex": "female",
#             "biosample_id": "SAME123665",
#             "population_code": "GIH",
#             "population_name": "Gujarati",
#             "superpopulation_code": "SAS",
#             "superpopulation_name": "South Asian Ancestry",
#             "population_elastic_id": "GIH",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release",
#             "cram_drs_uri": "drs://localhost:5000/7c50a9ef069868a93467ed0f165a5da6",
#             "crai_drs_uri": "drs://localhost:5000/ecb866c59ef2960fed8fbec8de298bdd",
#             "bundle_drs_uri": "drs://localhost:5000/1aff834fdfa7aa5429178d986e742068"
#         },
#         {
#             "sample_name": "HG01170",
#             "sex": "male",
#             "biosample_id": "SAME124623",
#             "population_code": "PUR",
#             "population_name": "Puerto Rican",
#             "superpopulation_code": "AMR",
#             "superpopulation_name": "American Ancestry",
#             "population_elastic_id": "PUR",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release,1000 Genomes phase 1 release",
#             "cram_drs_uri": "drs://localhost:5000/8b2f66fd2023e6d41e87d627f32b6f75",
#             "crai_drs_uri": "drs://localhost:5000/09d27dc0b24124e031cadc2451c012c1",
#             "bundle_drs_uri": "drs://localhost:5000/e74c8c868a5dca20dd5539cbd5bfc5fe"
#         },
#         {
#             "sample_name": "NA19026",
#             "sex": "male",
#             "biosample_id": "SAME124849",
#             "population_code": "LWK",
#             "population_name": "Luhya",
#             "superpopulation_code": "AFR",
#             "superpopulation_name": "African Ancestry",
#             "population_elastic_id": "LWK",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release",
#             "cram_drs_uri": "drs://localhost:5000/816542e61bb4a8021d1d62af6a944986",
#             "crai_drs_uri": "drs://localhost:5000/eb1883fec68f68d76b31adb497c2096d",
#             "bundle_drs_uri": "drs://localhost:5000/9cace3e69b71f5f66a2ea612ff92b58b"
#         },
#         {
#             "sample_name": "HG02546",
#             "sex": "female",
#             "biosample_id": "SAME1839932",
#             "population_code": "ACB",
#             "population_name": "African Caribbean",
#             "superpopulation_code": "AFR",
#             "superpopulation_name": "African Ancestry",
#             "population_elastic_id": "ACB",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release",
#             "cram_drs_uri": "drs://localhost:5000/15c8d652c641fd37f06a33b2f0b13942",
#             "crai_drs_uri": "drs://localhost:5000/2fde5c7a0aa17812913402ef290978a6",
#             "bundle_drs_uri": "drs://localhost:5000/710bd1e34f204b61bfa577b728890d65"
#         },
#         {
#             "sample_name": "HG00101",
#             "sex": "male",
#             "biosample_id": "SAME125153",
#             "population_code": "GBR",
#             "population_name": "British",
#             "superpopulation_code": "EUR",
#             "superpopulation_name": "European Ancestry",
#             "population_elastic_id": "GBR",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release,1000 Genomes phase 1 release,Geuvadis",
#             "cram_drs_uri": "drs://localhost:5000/04c2b4326d2340b12d9644804599bf0f",
#             "crai_drs_uri": "drs://localhost:5000/b5ac871e4fc5183a4d69790aa8636976",
#             "bundle_drs_uri": "drs://localhost:5000/494abaa43b22e08bd9e40d5e643e2b8b"
#         },
#         {
#             "sample_name": "HG00463",
#             "sex": "male",
#             "biosample_id": "SAME123496",
#             "population_code": "CHS",
#             "population_name": "Southern Han Chinese",
#             "superpopulation_code": "EAS",
#             "superpopulation_name": "East Asian Ancestry",
#             "population_elastic_id": "CHS",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release,1000 Genomes phase 1 release",
#             "cram_drs_uri": "drs://localhost:5000/d0162059095fa6c84c8875bf65423856",
#             "crai_drs_uri": "drs://localhost:5000/478446db02e17d933d7827ff6d2f0edd",
#             "bundle_drs_uri": "drs://localhost:5000/fec2d37b949da8cae71e0bc8f6885285"
#         },
#         {
#             "sample_name": "HG03711",
#             "sex": "male",
#             "biosample_id": "SAME1839894",
#             "population_code": "STU",
#             "population_name": "Tamil",
#             "superpopulation_code": "SAS",
#             "superpopulation_name": "South Asian Ancestry",
#             "population_elastic_id": "STU",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release",
#             "cram_drs_uri": "drs://localhost:5000/6f74c896b4ee2bb7fed7bf52c963d61e",
#             "crai_drs_uri": "drs://localhost:5000/91d05e6e89ac5dd6d15d8f7a22afa7fc",
#             "bundle_drs_uri": "drs://localhost:5000/4b978a11b9b905ff04c9dcb8b3c3ca1f"
#         },
#         {
#             "sample_name": "NA12413",
#             "sex": "male",
#             "biosample_id": "SAME124055",
#             "population_code": "CEU",
#             "population_name": "CEPH",
#             "superpopulation_code": "EUR",
#             "superpopulation_name": "European Ancestry",
#             "population_elastic_id": "CEU",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release,1000 Genomes phase 1 release,Geuvadis",
#             "cram_drs_uri": "drs://localhost:5000/bb721c7fdf98c69de0e4f7f166e5f5d6",
#             "crai_drs_uri": "drs://localhost:5000/87e8549ec0694d767086a53ab9543c90",
#             "bundle_drs_uri": "drs://localhost:5000/f24f53a0bce8f2c588828ad262cd0ef6"
#         },
#         {
#             "sample_name": "NA20811",
#             "sex": "male",
#             "biosample_id": "SAME123069",
#             "population_code": "TSI",
#             "population_name": "Toscani",
#             "superpopulation_code": "EUR",
#             "superpopulation_name": "European Ancestry",
#             "population_elastic_id": "TSI",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release,1000 Genomes phase 1 release,Geuvadis",
#             "cram_drs_uri": "drs://localhost:5000/f3f7ffa4203eb2723f1f477138cef1aa",
#             "crai_drs_uri": "drs://localhost:5000/94e393c569f4383a0120ac925425fde9",
#             "bundle_drs_uri": "drs://localhost:5000/34b8027d926bd07bf74367187ba639b9"
#         },
#         {
#             "sample_name": "HG03224",
#             "sex": "male",
#             "biosample_id": "SAME1839455",
#             "population_code": "MSL",
#             "population_name": "Mende",
#             "superpopulation_code": "AFR",
#             "superpopulation_name": "African Ancestry",
#             "population_elastic_id": "MSL",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release",
#             "cram_drs_uri": "drs://localhost:5000/8d13dd4593417363fa3b0e39b3396e45",
#             "crai_drs_uri": "drs://localhost:5000/ae6a1bcaa5fe3885e34a3139f9667ffd",
#             "bundle_drs_uri": "drs://localhost:5000/9cee8b600b234aede29cbce144317de5"
#         },
#         {
#             "sample_name": "NA20541",
#             "sex": "female",
#             "biosample_id": "SAME125147",
#             "population_code": "TSI",
#             "population_name": "Toscani",
#             "superpopulation_code": "EUR",
#             "superpopulation_name": "European Ancestry",
#             "population_elastic_id": "TSI",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release,1000 Genomes phase 1 release,Geuvadis",
#             "cram_drs_uri": "drs://localhost:5000/24bb23c89b9d6278a20ec978fb944d0a",
#             "crai_drs_uri": "drs://localhost:5000/1e357421ecaa1d683533f299e347c83d",
#             "bundle_drs_uri": "drs://localhost:5000/82ca66d2f34a2718fad876d1b320236f"
#         },
#         {
#             "sample_name": "NA19443",
#             "sex": "male",
#             "biosample_id": "SAME122954",
#             "population_code": "LWK",
#             "population_name": "Luhya",
#             "superpopulation_code": "AFR",
#             "superpopulation_name": "African Ancestry",
#             "population_elastic_id": "LWK",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release,1000 Genomes phase 1 release",
#             "cram_drs_uri": "drs://localhost:5000/eb893ff8ef8ecbb5475786c7364a3730",
#             "crai_drs_uri": "drs://localhost:5000/b61918c2ee45f6dfe4f41c1d637d0186",
#             "bundle_drs_uri": "drs://localhost:5000/2dd8083ddc82b2ef5587f2bfc51b48a0"
#         },
#         {
#             "sample_name": "HG03451",
#             "sex": "male",
#             "biosample_id": "SAME1840043",
#             "population_code": "MSL",
#             "population_name": "Mende",
#             "superpopulation_code": "AFR",
#             "superpopulation_name": "African Ancestry",
#             "population_elastic_id": "MSL",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release",
#             "cram_drs_uri": "drs://localhost:5000/4a2af06cb64949669eb8f822e52e4e7e",
#             "crai_drs_uri": "drs://localhost:5000/42b601538e3a11c42ab300c3f2e00a15",
#             "bundle_drs_uri": "drs://localhost:5000/6c3cab755c552d7869eb7a5f4cb0f527"
#         },
#         {
#             "sample_name": "NA12716",
#             "sex": "male",
#             "biosample_id": "SAME123912",
#             "population_code": "CEU",
#             "population_name": "CEPH",
#             "superpopulation_code": "EUR",
#             "superpopulation_name": "European Ancestry",
#             "population_elastic_id": "CEU",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release,1000 Genomes phase 1 release,Geuvadis",
#             "cram_drs_uri": "drs://localhost:5000/acc9018e8879667b06532ef4b97b1bfb",
#             "crai_drs_uri": "drs://localhost:5000/5ee042baf056a99b96ef8ef42c842ef0",
#             "bundle_drs_uri": "drs://localhost:5000/4d203278929224b7891f7d0a78824b92"
#         },
#         {
#             "sample_name": "HG02181",
#             "sex": "female",
#             "biosample_id": "SAME123206",
#             "population_code": "CDX",
#             "population_name": "Dai Chinese",
#             "superpopulation_code": "EAS",
#             "superpopulation_name": "East Asian Ancestry",
#             "population_elastic_id": "CDX",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release",
#             "cram_drs_uri": "drs://localhost:5000/5eae8e2721dae1f4549aca2b58cdf390",
#             "crai_drs_uri": "drs://localhost:5000/6f81b522914b6c9f36a4c7e6a12ab1c4",
#             "bundle_drs_uri": "drs://localhost:5000/1f14972129cb2158d5bdc24181223104"
#         },
#         {
#             "sample_name": "NA20911",
#             "sex": "male",
#             "biosample_id": "SAME123101",
#             "population_code": "GIH",
#             "population_name": "Gujarati",
#             "superpopulation_code": "SAS",
#             "superpopulation_name": "South Asian Ancestry",
#             "population_elastic_id": "GIH",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release",
#             "cram_drs_uri": "drs://localhost:5000/6222bbc71d73f372586ef2def92e8c7a",
#             "crai_drs_uri": "drs://localhost:5000/fd87721c242a93046c669d766a9b4c3e",
#             "bundle_drs_uri": "drs://localhost:5000/0045077ccfaa91681480e96d7e7e7809"
#         },
#         {
#             "sample_name": "HG01173",
#             "sex": "male",
#             "biosample_id": "SAME124624",
#             "population_code": "PUR",
#             "population_name": "Puerto Rican",
#             "superpopulation_code": "AMR",
#             "superpopulation_name": "American Ancestry",
#             "population_elastic_id": "PUR",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release,1000 Genomes phase 1 release",
#             "cram_drs_uri": "drs://localhost:5000/6728575944f6ba3005518a74e7845334",
#             "crai_drs_uri": "drs://localhost:5000/fbe6f83d4145485144bac5b4f77b9438",
#             "bundle_drs_uri": "drs://localhost:5000/4c5cd80092fb9ca8db7ec37c4a055801"
#         },
#         {
#             "sample_name": "HG04014",
#             "sex": "female",
#             "biosample_id": "SAME1839844",
#             "population_code": "ITU",
#             "population_name": "Telugu",
#             "superpopulation_code": "SAS",
#             "superpopulation_name": "South Asian Ancestry",
#             "population_elastic_id": "ITU",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release",
#             "cram_drs_uri": "drs://localhost:5000/bb2a2c954e213b33b83bea4bb95d2fb1",
#             "crai_drs_uri": "drs://localhost:5000/ca536bf61559c5e2ee3c000c9490d9d6",
#             "bundle_drs_uri": "drs://localhost:5000/b5d7f942976463336da4d062586bac5b"
#         },
#         {
#             "sample_name": "HG01915",
#             "sex": "female",
#             "biosample_id": "SAME1839757",
#             "population_code": "ACB",
#             "population_name": "African Caribbean",
#             "superpopulation_code": "AFR",
#             "superpopulation_name": "African Ancestry",
#             "population_elastic_id": "ACB",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release",
#             "cram_drs_uri": "drs://localhost:5000/749f0ae96a54ebb5e1948740f5c4c1b2",
#             "crai_drs_uri": "drs://localhost:5000/c70e54f5a8061447e9ae5faeba556d7b",
#             "bundle_drs_uri": "drs://localhost:5000/a210fe5ff3324cee857eac2b8aaaaa47"
#         },
#         {
#             "sample_name": "NA20515",
#             "sex": "male",
#             "biosample_id": "SAME124559",
#             "population_code": "TSI",
#             "population_name": "Toscani",
#             "superpopulation_code": "EUR",
#             "superpopulation_name": "European Ancestry",
#             "population_elastic_id": "TSI",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release,1000 Genomes phase 1 release,Geuvadis",
#             "cram_drs_uri": "drs://localhost:5000/ba695f920678f6b2389a06458c9d953c",
#             "crai_drs_uri": "drs://localhost:5000/7f2fb6d9735e087518a1fa25ac70009e",
#             "bundle_drs_uri": "drs://localhost:5000/3e5e77d9c1406ffa2834ce2b568e267e"
#         },
#         {
#             "sample_name": "HG03867",
#             "sex": "male",
#             "biosample_id": "SAME1840095",
#             "population_code": "ITU",
#             "population_name": "Telugu",
#             "superpopulation_code": "SAS",
#             "superpopulation_name": "South Asian Ancestry",
#             "population_elastic_id": "ITU",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release",
#             "cram_drs_uri": "drs://localhost:5000/0cb6e190ef2ee483d0a807cdd43ab73a",
#             "crai_drs_uri": "drs://localhost:5000/ee50c20842bf8637372d9189c7802938",
#             "bundle_drs_uri": "drs://localhost:5000/b26426cc9e789091e9205b60aa5db7c3"
#         },
#         {
#             "sample_name": "HG00118",
#             "sex": "female",
#             "biosample_id": "SAME125347",
#             "population_code": "GBR",
#             "population_name": "British",
#             "superpopulation_code": "EUR",
#             "superpopulation_name": "European Ancestry",
#             "population_elastic_id": "GBR",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release,1000 Genomes phase 1 release,Geuvadis",
#             "cram_drs_uri": "drs://localhost:5000/2f508985f32255d304736ff2c199036a",
#             "crai_drs_uri": "drs://localhost:5000/1a3c2e0cb134e5bb6417f9288b981895",
#             "bundle_drs_uri": "drs://localhost:5000/2c53489e307445d5e4b9ee4a36e8df34"
#         },
#         {
#             "sample_name": "HG03943",
#             "sex": "male",
#             "biosample_id": "SAME1840361",
#             "population_code": "STU",
#             "population_name": "Tamil",
#             "superpopulation_code": "SAS",
#             "superpopulation_name": "South Asian Ancestry",
#             "population_elastic_id": "STU",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release",
#             "cram_drs_uri": "drs://localhost:5000/4f6b9e7f37658fbe1ddedd7a1573e7bb",
#             "crai_drs_uri": "drs://localhost:5000/013e3157ffb831d91cc8c7690dbffc65",
#             "bundle_drs_uri": "drs://localhost:5000/6bf02aba6c989a44fc4398804be36a4a"
#         },
#         {
#             "sample_name": "HG00113",
#             "sex": "male",
#             "biosample_id": "SAME125342",
#             "population_code": "GBR",
#             "population_name": "British",
#             "superpopulation_code": "EUR",
#             "superpopulation_name": "European Ancestry",
#             "population_elastic_id": "GBR",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release,1000 Genomes phase 1 release",
#             "cram_drs_uri": "drs://localhost:5000/af2b9cfea8fd23bfcc8fc4b2ba5eb437",
#             "crai_drs_uri": "drs://localhost:5000/0ac8cb013021cce11036ff64b1109211",
#             "bundle_drs_uri": "drs://localhost:5000/e449a8dba3bdcf7b377f50e3014cc207"
#         },
#         {
#             "sample_name": "NA20853",
#             "sex": "female",
#             "biosample_id": "SAME123243",
#             "population_code": "GIH",
#             "population_name": "Gujarati",
#             "superpopulation_code": "SAS",
#             "superpopulation_name": "South Asian Ancestry",
#             "population_elastic_id": "GIH",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release",
#             "cram_drs_uri": "drs://localhost:5000/6dc1dd57d5167c93e0803237d843db29",
#             "crai_drs_uri": "drs://localhost:5000/d3da2b0c64b036fa4a747a93b60aa804",
#             "bundle_drs_uri": "drs://localhost:5000/8c5f46e0c2116a5712bf363b8574b5ec"
#         },
#         {
#             "sample_name": "HG03300",
#             "sex": "female",
#             "biosample_id": "SAME1839467",
#             "population_code": "ESN",
#             "population_name": "Esan",
#             "superpopulation_code": "AFR",
#             "superpopulation_name": "African Ancestry",
#             "population_elastic_id": "ESN",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release",
#             "cram_drs_uri": "drs://localhost:5000/43735e14168783228db1e7b620bd6796",
#             "crai_drs_uri": "drs://localhost:5000/b4fe99d0b0b1e9f6c74f834a11983fb1",
#             "bundle_drs_uri": "drs://localhost:5000/86d72d286364e61b232c06c3962b4965"
#         },
#         {
#             "sample_name": "NA18620",
#             "sex": "male",
#             "biosample_id": "SAME124510",
#             "population_code": "CHB",
#             "population_name": "Han Chinese",
#             "superpopulation_code": "EAS",
#             "superpopulation_name": "East Asian Ancestry",
#             "population_elastic_id": "CHB",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release,1000 Genomes phase 1 release,90 Han Chinese high coverage genomes",
#             "cram_drs_uri": "drs://localhost:5000/c7901d63b96ef6d57f0cde04c46bade6",
#             "crai_drs_uri": "drs://localhost:5000/1400236b00f626dc5338d928eabffe2a",
#             "bundle_drs_uri": "drs://localhost:5000/bb9845d4b39429658e691b8cb90e8462"
#         },
#         {
#             "sample_name": "HG00864",
#             "sex": "female",
#             "biosample_id": "SAME123547",
#             "population_code": "CDX",
#             "population_name": "Dai Chinese",
#             "superpopulation_code": "EAS",
#             "superpopulation_name": "East Asian Ancestry",
#             "population_elastic_id": "CDX",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,Human Genome Structural Variation Consortium, Phase 2,1000 Genomes phase 3 release",
#             "cram_drs_uri": "drs://localhost:5000/ebf03c22bf2ca34b0e492a828d752080",
#             "crai_drs_uri": "drs://localhost:5000/cbdb71bd05eeb14d95d724bf719c8aa5",
#             "bundle_drs_uri": "drs://localhost:5000/a520031d627afbe15468ae392d8d3a87"
#         },
#         {
#             "sample_name": "HG01790",
#             "sex": "female",
#             "biosample_id": "SAME124222",
#             "population_code": "GBR",
#             "population_name": "British",
#             "superpopulation_code": "EUR",
#             "superpopulation_name": "European Ancestry",
#             "population_elastic_id": "GBR",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release,Geuvadis",
#             "cram_drs_uri": "drs://localhost:5000/bdde12356d29f0d861b73821065f13c6",
#             "crai_drs_uri": "drs://localhost:5000/00337cf1eb2124898e721064dd1e5398",
#             "bundle_drs_uri": "drs://localhost:5000/8abf868cc1e3ba703fd5052ddcc2b4eb"
#         },
#         {
#             "sample_name": "NA19310",
#             "sex": "female",
#             "biosample_id": "SAME123449",
#             "population_code": "LWK",
#             "population_name": "Luhya",
#             "superpopulation_code": "AFR",
#             "superpopulation_name": "African Ancestry",
#             "population_elastic_id": "LWK",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release,1000 Genomes phase 1 release",
#             "cram_drs_uri": "drs://localhost:5000/05defa063f233b40e0bb12744f4a1118",
#             "crai_drs_uri": "drs://localhost:5000/d4750798da0680c7653335f2856925a9",
#             "bundle_drs_uri": "drs://localhost:5000/f95a19360a35b54580fec194f29935ff"
#         },
#         {
#             "sample_name": "HG00125",
#             "sex": "female",
#             "biosample_id": "SAME122869",
#             "population_code": "GBR",
#             "population_name": "British",
#             "superpopulation_code": "EUR",
#             "superpopulation_name": "European Ancestry",
#             "population_elastic_id": "GBR",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release,1000 Genomes phase 1 release,Geuvadis",
#             "cram_drs_uri": "drs://localhost:5000/ff5f5444c2828ed5cc81db76e0fc7372",
#             "crai_drs_uri": "drs://localhost:5000/b97f92d90fbdd990227bb9173dfe0fc2",
#             "bundle_drs_uri": "drs://localhost:5000/2859904f4cb07312f0151ff3bd8fd805"
#         },
#         {
#             "sample_name": "NA18534",
#             "sex": "male",
#             "biosample_id": "SAME124488",
#             "population_code": "CHB",
#             "population_name": "Han Chinese",
#             "superpopulation_code": "EAS",
#             "superpopulation_name": "East Asian Ancestry",
#             "population_elastic_id": "CHB",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,Human Genome Structural Variation Consortium, Phase 2,1000 Genomes phase 3 release,1000 Genomes phase 1 release",
#             "cram_drs_uri": "drs://localhost:5000/115822589cfeec4c698d60dfcfd15fb8",
#             "crai_drs_uri": "drs://localhost:5000/b4f518ff4fe438c9560b4483c4d55252",
#             "bundle_drs_uri": "drs://localhost:5000/91d43b0fb720b3d3041a486985ea652e"
#         },
#         {
#             "sample_name": "NA20874",
#             "sex": "female",
#             "biosample_id": "SAME123597",
#             "population_code": "GIH",
#             "population_name": "Gujarati",
#             "superpopulation_code": "SAS",
#             "superpopulation_name": "South Asian Ancestry",
#             "population_elastic_id": "GIH",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release",
#             "cram_drs_uri": "drs://localhost:5000/ea0251cd5548bbb645cad9a234c71b3c",
#             "crai_drs_uri": "drs://localhost:5000/8e503ecc422eb98b8f7556e6f159d7fa",
#             "bundle_drs_uri": "drs://localhost:5000/b90c40898b50f4ec84842f65ec6dde7d"
#         },
#         {
#             "sample_name": "HG01384",
#             "sex": "female",
#             "biosample_id": "SAME122969",
#             "population_code": "CLM",
#             "population_name": "Colombian",
#             "superpopulation_code": "AMR",
#             "superpopulation_name": "American Ancestry",
#             "population_elastic_id": "CLM",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release,1000 Genomes phase 1 release",
#             "cram_drs_uri": "drs://localhost:5000/7618c97b0499a0a687accb6881848b5b",
#             "crai_drs_uri": "drs://localhost:5000/d276d67845f5a8d830cb58a50730b989",
#             "bundle_drs_uri": "drs://localhost:5000/489b38b80ce1da6dce820e7265a5aa1a"
#         },
#         {
#             "sample_name": "HG04118",
#             "sex": "female",
#             "biosample_id": "SAME1839379",
#             "population_code": "ITU",
#             "population_name": "Telugu",
#             "superpopulation_code": "SAS",
#             "superpopulation_name": "South Asian Ancestry",
#             "population_elastic_id": "ITU",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release",
#             "cram_drs_uri": "drs://localhost:5000/169248eb90c80ce253b9dc8f9beb062b",
#             "crai_drs_uri": "drs://localhost:5000/7664b68c34cac57d1b6f81a84ff5be15",
#             "bundle_drs_uri": "drs://localhost:5000/0bdee58712a7539f314de6d931b96cf7"
#         },
#         {
#             "sample_name": "NA19089",
#             "sex": "male",
#             "biosample_id": "SAME123649",
#             "population_code": "JPT",
#             "population_name": "Japanese",
#             "superpopulation_code": "EAS",
#             "superpopulation_name": "East Asian Ancestry",
#             "population_elastic_id": "JPT",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release",
#             "cram_drs_uri": "drs://localhost:5000/4ebee4b76631cfb631f6c05c224e7d93",
#             "crai_drs_uri": "drs://localhost:5000/0739b81b48bfd95a9cd7addc516b058b",
#             "bundle_drs_uri": "drs://localhost:5000/3e0228036a9431e93ebaf43772639d63"
#         },
#         {
#             "sample_name": "HG02318",
#             "sex": "female",
#             "biosample_id": "SAME1839391",
#             "population_code": "ACB",
#             "population_name": "African Caribbean",
#             "superpopulation_code": "AFR",
#             "superpopulation_name": "African Ancestry",
#             "population_elastic_id": "ACB",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release",
#             "cram_drs_uri": "drs://localhost:5000/f932cc5dc9ecfda9dd2e139308175213",
#             "crai_drs_uri": "drs://localhost:5000/8af2094a87e1d7d2aafbe0b6fa54f455",
#             "bundle_drs_uri": "drs://localhost:5000/91311a04d76b62162ca1244b97bb44f8"
#         },
#         {
#             "sample_name": "HG00284",
#             "sex": "male",
#             "biosample_id": "SAME122835",
#             "population_code": "FIN",
#             "population_name": "Finnish",
#             "superpopulation_code": "EUR",
#             "superpopulation_name": "European Ancestry",
#             "population_elastic_id": "FIN",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release,1000 Genomes phase 1 release,Geuvadis",
#             "cram_drs_uri": "drs://localhost:5000/037663ece6551b4406f8c50fdb13f2fe",
#             "crai_drs_uri": "drs://localhost:5000/7489047de8eb71ba3491c45395ced0a4",
#             "bundle_drs_uri": "drs://localhost:5000/e5399066421ca3b4934a240107414106"
#         },
#         {
#             "sample_name": "HG01565",
#             "sex": "male",
#             "biosample_id": "SAME124566",
#             "population_code": "PEL",
#             "population_name": "Peruvian",
#             "superpopulation_code": "AMR",
#             "superpopulation_name": "American Ancestry",
#             "population_elastic_id": "PEL",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release",
#             "cram_drs_uri": "drs://localhost:5000/12c02f93014ab2d687f766579023dba7",
#             "crai_drs_uri": "drs://localhost:5000/5f3029e0cbbb1ce9f134ec671cf3cec2",
#             "bundle_drs_uri": "drs://localhost:5000/195bc6fcec83aa469cbd150ab20fa519"
#         },
#         {
#             "sample_name": "NA19092",
#             "sex": "male",
#             "biosample_id": "SAME123173",
#             "population_code": "YRI",
#             "population_name": "Yoruba",
#             "superpopulation_code": "AFR",
#             "superpopulation_name": "African Ancestry",
#             "population_elastic_id": "YRI",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release,1000 Genomes phase 1 release,Geuvadis",
#             "cram_drs_uri": "drs://localhost:5000/d7a152ab0ae6e48c6c70a489e479a26d",
#             "crai_drs_uri": "drs://localhost:5000/ff4335ad5fd3653db17b0e4080eb00eb",
#             "bundle_drs_uri": "drs://localhost:5000/36d84899ef14f90fd7c68082cc488c35"
#         },
#         {
#             "sample_name": "NA19095",
#             "sex": "female",
#             "biosample_id": "SAME123170",
#             "population_code": "YRI",
#             "population_name": "Yoruba",
#             "superpopulation_code": "AFR",
#             "superpopulation_name": "African Ancestry",
#             "population_elastic_id": "YRI",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release,1000 Genomes phase 1 release,Geuvadis",
#             "cram_drs_uri": "drs://localhost:5000/794418c5b9830c5f3f91957e3e45d76d",
#             "crai_drs_uri": "drs://localhost:5000/69808d1b34f3ca994267c142f78955c4",
#             "bundle_drs_uri": "drs://localhost:5000/8f3dd45d30ee22a590b60af0c8dd37c0"
#         },
#         {
#             "sample_name": "HG03572",
#             "sex": "female",
#             "biosample_id": "SAME1839463",
#             "population_code": "MSL",
#             "population_name": "Mende",
#             "superpopulation_code": "AFR",
#             "superpopulation_name": "African Ancestry",
#             "population_elastic_id": "MSL",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release",
#             "cram_drs_uri": "drs://localhost:5000/cca61300bfa73db517b17b274b76540c",
#             "crai_drs_uri": "drs://localhost:5000/ca67cfd70c9a603ba00a76168333dce7",
#             "bundle_drs_uri": "drs://localhost:5000/ffe7281ace7c101fea3fe8c0fb049c2f"
#         },
#         {
#             "sample_name": "NA20851",
#             "sex": "female",
#             "biosample_id": "SAME123245",
#             "population_code": "GIH",
#             "population_name": "Gujarati",
#             "superpopulation_code": "SAS",
#             "superpopulation_name": "South Asian Ancestry",
#             "population_elastic_id": "GIH",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release",
#             "cram_drs_uri": "drs://localhost:5000/1b77652632b6eeacfc26d9f0b7ae5111",
#             "crai_drs_uri": "drs://localhost:5000/a87033aae99f7d76a56b96a15bdc2cba",
#             "bundle_drs_uri": "drs://localhost:5000/96116a520ebfd47e569e5c19887272fa"
#         },
#         {
#             "sample_name": "NA20866",
#             "sex": "male",
#             "biosample_id": "SAME123808",
#             "population_code": "GIH",
#             "population_name": "Gujarati",
#             "superpopulation_code": "SAS",
#             "superpopulation_name": "South Asian Ancestry",
#             "population_elastic_id": "GIH",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release",
#             "cram_drs_uri": "drs://localhost:5000/06e0d74951224f2de367c24469d5ccd8",
#             "crai_drs_uri": "drs://localhost:5000/f0b9f0573486a30ad2f9181695c39df0",
#             "bundle_drs_uri": "drs://localhost:5000/cfd404874fd6e055d60bf7acf0eaa465"
#         },
#         {
#             "sample_name": "HG02817",
#             "sex": "female",
#             "biosample_id": "SAME1839819",
#             "population_code": "GWD",
#             "population_name": "Gambian Mandinka",
#             "superpopulation_code": "AFR",
#             "superpopulation_name": "African Ancestry",
#             "population_elastic_id": "GWD",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release,Gambian Genome Variation Project (GRCh38)",
#             "cram_drs_uri": "drs://localhost:5000/54240d03f55e0c69958e0ac22ae4f038",
#             "crai_drs_uri": "drs://localhost:5000/94e94da4b6a189257e9888656964c1f6",
#             "bundle_drs_uri": "drs://localhost:5000/b40af64ca7d97401260a594fa4e07af6"
#         },
#         {
#             "sample_name": "HG02685",
#             "sex": "female",
#             "biosample_id": "SAME1839286",
#             "population_code": "PJL",
#             "population_name": "Punjabi",
#             "superpopulation_code": "SAS",
#             "superpopulation_name": "South Asian Ancestry",
#             "population_elastic_id": "PJL",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release",
#             "cram_drs_uri": "drs://localhost:5000/9ab4d5fc7b954dad71934450c7552784",
#             "crai_drs_uri": "drs://localhost:5000/9961bbed21c00ef63b27624a2fade24d",
#             "bundle_drs_uri": "drs://localhost:5000/0361b5dba4d3a3fa46032604a0d1a4c5"
#         },
#         {
#             "sample_name": "NA19713",
#             "sex": "female",
#             "biosample_id": "SAME124448",
#             "population_code": "ASW",
#             "population_name": "African Ancestry SW",
#             "superpopulation_code": "AFR",
#             "superpopulation_name": "African Ancestry",
#             "population_elastic_id": "ASW",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release,1000 Genomes phase 1 release",
#             "cram_drs_uri": "drs://localhost:5000/66faa6403ceb34e454294be98b4d13b8",
#             "crai_drs_uri": "drs://localhost:5000/9214791f6c33f2afb07d82e396237c39",
#             "bundle_drs_uri": "drs://localhost:5000/6d7804b567593089985d2af9f33f1e7a"
#         },
#         {
# ...
#             "crai_drs_uri": "drs://localhost:5000/35712afd72bb8570e5c905f4e0108556",
#             "bundle_drs_uri": "drs://localhost:5000/861664bf35ac9eedd3f9d68b2d464fcd"
#         },
#         {
#             "sample_name": "HG00473",
#             "sex": "female",
#             "biosample_id": "SAME123338",
#             "population_code": "CHS",
#             "population_name": "Southern Han Chinese",
#             "superpopulation_code": "EAS",
#             "superpopulation_name": "East Asian Ancestry",
#             "population_elastic_id": "CHS",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release,1000 Genomes phase 1 release,90 Han Chinese high coverage genomes",
#             "cram_drs_uri": "drs://localhost:5000/755860ae0ca239025dcaaa70988e40d8",
#             "crai_drs_uri": "drs://localhost:5000/bed85178ff0aefb6587faadc3d16edb6",
#             "bundle_drs_uri": "drs://localhost:5000/a506a79f523038e29e2c93f5d331297c"
#         },
#         {
#             "sample_name": "HG00620",
#             "sex": "female",
#             "biosample_id": "SAME123081",
#             "population_code": "CHS",
#             "population_name": "Southern Han Chinese",
#             "superpopulation_code": "EAS",
#             "superpopulation_name": "East Asian Ancestry",
#             "population_elastic_id": "CHS",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release,1000 Genomes phase 1 release,90 Han Chinese high coverage genomes",
#             "cram_drs_uri": "drs://localhost:5000/01702a995fa13028c1539c9b11510951",
#             "crai_drs_uri": "drs://localhost:5000/2c4a9d26a8580fdafb0c7d3b74e738f8",
#             "bundle_drs_uri": "drs://localhost:5000/3df9d6acbe1b193d951b38150db39d4d"
#         },
#         {
#             "sample_name": "HG01509",
#             "sex": "male",
#             "biosample_id": "SAME124940",
#             "population_code": "IBS",
#             "population_name": "Iberian",
#             "superpopulation_code": "EUR",
#             "superpopulation_name": "European Ancestry",
#             "population_elastic_id": "IBS",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release",
#             "cram_drs_uri": "drs://localhost:5000/190a6e882e78d5113c392f1abcd77047",
#             "crai_drs_uri": "drs://localhost:5000/7042b581811a154c5653c2ec6d4fc693",
#             "bundle_drs_uri": "drs://localhost:5000/3c3649f38f6b0ae8a100ded0cd0af605"
#         },
#         {
#             "sample_name": "HG00656",
#             "sex": "male",
#             "biosample_id": "SAME123233",
#             "population_code": "CHS",
#             "population_name": "Southern Han Chinese",
#             "superpopulation_code": "EAS",
#             "superpopulation_name": "East Asian Ancestry",
#             "population_elastic_id": "CHS",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release,1000 Genomes phase 1 release,90 Han Chinese high coverage genomes",
#             "cram_drs_uri": "drs://localhost:5000/93613a94bb6c033490401ec6a2266517",
#             "crai_drs_uri": "drs://localhost:5000/1a510e9fe637a1dcd433929d94b21b9b",
#             "bundle_drs_uri": "drs://localhost:5000/f53c6e13f50fe1aca7c11556218acc51"
#         },
#         {
#             "sample_name": "NA18582",
#             "sex": "female",
#             "biosample_id": "SAME123905",
#             "population_code": "CHB",
#             "population_name": "Han Chinese",
#             "superpopulation_code": "EAS",
#             "superpopulation_name": "East Asian Ancestry",
#             "population_elastic_id": "CHB",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release,1000 Genomes phase 1 release,90 Han Chinese high coverage genomes",
#             "cram_drs_uri": "drs://localhost:5000/cdcbb1f67c928d98d7be6ad94d5bb4d0",
#             "crai_drs_uri": "drs://localhost:5000/bb7c5461f57605995041edc24a3f7f3a",
#             "bundle_drs_uri": "drs://localhost:5000/78a0d2ddc40a70e1ad29ecc9ec1c6aa6"
#         },
#         {
#             "sample_name": "HG03196",
#             "sex": "male",
#             "biosample_id": "SAME1839921",
#             "population_code": "ESN",
#             "population_name": "Esan",
#             "superpopulation_code": "AFR",
#             "superpopulation_name": "African Ancestry",
#             "population_elastic_id": "ESN",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release",
#             "cram_drs_uri": "drs://localhost:5000/9cb3a4d11433155a006285a2bed2d902",
#             "crai_drs_uri": "drs://localhost:5000/412dd269311d4f0c574641f8204b799c",
#             "bundle_drs_uri": "drs://localhost:5000/6ce770f98399b48c68b24fe66b569644"
#         },
#         {
#             "sample_name": "HG01598",
#             "sex": "female",
#             "biosample_id": "SAME125239",
#             "population_code": "KHV",
#             "population_name": "Kinh Vietnamese",
#             "superpopulation_code": "EAS",
#             "superpopulation_name": "East Asian Ancestry",
#             "population_elastic_id": "KHV",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release",
#             "cram_drs_uri": "drs://localhost:5000/e09037e8547067381b212a32d6840f1f",
#             "crai_drs_uri": "drs://localhost:5000/705f2dfca548ea186820525d97f3a29d",
#             "bundle_drs_uri": "drs://localhost:5000/56def470ae8913f5c7e4d2c0d6e8e91d"
#         },
#         {
#             "sample_name": "HG03114",
#             "sex": "female",
#             "biosample_id": "SAME1839907",
#             "population_code": "ESN",
#             "population_name": "Esan",
#             "superpopulation_code": "AFR",
#             "superpopulation_name": "African Ancestry",
#             "population_elastic_id": "ESN",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release",
#             "cram_drs_uri": "drs://localhost:5000/c1ef760289690846c3a755a5437c9972",
#             "crai_drs_uri": "drs://localhost:5000/ec3ba30b6a629c7b521c621cf17e6be5",
#             "bundle_drs_uri": "drs://localhost:5000/20e67408ce9c6ba3c56e38c1f073b076"
#         },
#         {
#             "sample_name": "HG02505",
#             "sex": "female",
#             "biosample_id": "SAME1839351",
#             "population_code": "ACB",
#             "population_name": "African Caribbean",
#             "superpopulation_code": "AFR",
#             "superpopulation_name": "African Ancestry",
#             "population_elastic_id": "ACB",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release",
#             "cram_drs_uri": "drs://localhost:5000/b303ee11accb89e93a9d7275f298441c",
#             "crai_drs_uri": "drs://localhost:5000/76afd5f8d97fd82157f5d43668b8fe25",
#             "bundle_drs_uri": "drs://localhost:5000/9925b88059dfe1f8c8b4756a01d1c7c6"
#         },
#         {
#             "sample_name": "NA20581",
#             "sex": "male",
#             "biosample_id": "SAME122859",
#             "population_code": "TSI",
#             "population_name": "Toscani",
#             "superpopulation_code": "EUR",
#             "superpopulation_name": "European Ancestry",
#             "population_elastic_id": "TSI",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release,1000 Genomes phase 1 release,Geuvadis",
#             "cram_drs_uri": "drs://localhost:5000/f9ec012ceecc76306e206783c288c602",
#             "crai_drs_uri": "drs://localhost:5000/d577f670ad44efeae27f71461341f618",
#             "bundle_drs_uri": "drs://localhost:5000/033d39024cab88a45ccca0ffd5fcc7ff"
#         },
#         {
#             "sample_name": "NA20812",
#             "sex": "male",
#             "biosample_id": "SAME125190",
#             "population_code": "TSI",
#             "population_name": "Toscani",
#             "superpopulation_code": "EUR",
#             "superpopulation_name": "European Ancestry",
#             "population_elastic_id": "TSI",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release,1000 Genomes phase 1 release,Geuvadis",
#             "cram_drs_uri": "drs://localhost:5000/99112f40932ccbe00facd4df486320b1",
#             "crai_drs_uri": "drs://localhost:5000/3ff1b2eb48b44157705a62ca26927f7c",
#             "bundle_drs_uri": "drs://localhost:5000/8a5e35cc50961e626c7625269f00a0f7"
#         },
#         {
#             "sample_name": "HG01524",
#             "sex": "male",
#             "biosample_id": "SAME125327",
#             "population_code": "IBS",
#             "population_name": "Iberian",
#             "superpopulation_code": "EUR",
#             "superpopulation_name": "European Ancestry",
#             "population_elastic_id": "IBS",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release",
#             "cram_drs_uri": "drs://localhost:5000/1c1b2d632a0ca6d6d9345b984a71d6af",
#             "crai_drs_uri": "drs://localhost:5000/f9dcaa160eb42fe53cc5112f686aca60",
#             "bundle_drs_uri": "drs://localhost:5000/bb17486f097de779da34eda9cf189705"
#         },
#         {
#             "sample_name": "NA19313",
#             "sex": "female",
#             "biosample_id": "SAME123316",
#             "population_code": "LWK",
#             "population_name": "Luhya",
#             "superpopulation_code": "AFR",
#             "superpopulation_name": "African Ancestry",
#             "population_elastic_id": "LWK",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes phase 3 release,1000 Genomes phase 1 release",
#             "cram_drs_uri": "drs://localhost:5000/85f0797dfd3c72d7bfe3d26cbec3e566",
#             "crai_drs_uri": "drs://localhost:5000/27024533da3af166c1fad2306000ef26",
#             "bundle_drs_uri": "drs://localhost:5000/071a663a5839e77e066fcad7754a9398"
#         },
#         {
#             "sample_name": "HG02783",
#             "sex": "male",
#             "biosample_id": "SAME1839162",
#             "population_code": "PJL",
#             "population_name": "Punjabi,Punjabi",
#             "superpopulation_code": "SAS",
#             "superpopulation_name": "South Asia (SGDP),South Asian Ancestry",
#             "population_elastic_id": "PunjabiSGDP,PJL",
#             "data_collections": "1000 Genomes on GRCh38,Simons Genome Diversity Project,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release",
#             "cram_drs_uri": "drs://localhost:5000/7ccce6cc0d81893379b2a0e5d526a122",
#             "crai_drs_uri": "drs://localhost:5000/60a52c824b5500f0a2fdef8e6c6a23ae",
#             "bundle_drs_uri": "drs://localhost:5000/6730d1a13a7f532c4c2eda82bfcf6311"
#         },
#         {
#             "sample_name": "HG02334",
#             "sex": "male",
#             "biosample_id": "SAME1839307",
#             "population_code": "ACB",
#             "population_name": "African Caribbean",
#             "superpopulation_code": "AFR",
#             "superpopulation_name": "African Ancestry",
#             "population_elastic_id": "ACB",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release",
#             "cram_drs_uri": "drs://localhost:5000/519629c32264d54710e7237a82c876d8",
#             "crai_drs_uri": "drs://localhost:5000/19ff88644afb2011d996501a382b669c",
#             "bundle_drs_uri": "drs://localhost:5000/a551182e05e5c26a76a23b4b9e1b69e8"
#         },
#         {
#             "sample_name": "HG01326",
#             "sex": "female",
#             "biosample_id": "SAME1839598",
#             "population_code": "PUR",
#             "population_name": "Puerto Rican",
#             "superpopulation_code": "AMR",
#             "superpopulation_name": "American Ancestry",
#             "population_elastic_id": "PUR",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release",
#             "cram_drs_uri": "drs://localhost:5000/238f677cfd2a15e84f1fb0f61f9cd5ae",
#             "crai_drs_uri": "drs://localhost:5000/431447987fd19b63bb7a52e16adfd242",
#             "bundle_drs_uri": "drs://localhost:5000/ce5d893e4174fc13c21bcfff91c03dc7"
#         },
#         {
#             "sample_name": "NA20821",
#             "sex": "female",
#             "biosample_id": "SAME123075",
#             "population_code": "TSI",
#             "population_name": "Toscani",
#             "superpopulation_code": "EUR",
#             "superpopulation_name": "European Ancestry",
#             "population_elastic_id": "TSI",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release",
#             "cram_drs_uri": "drs://localhost:5000/591421e50f3350ee4ca5ce51de03ba90",
#             "crai_drs_uri": "drs://localhost:5000/5208f0f0ae6d8057559aa6f39caac71a",
#             "bundle_drs_uri": "drs://localhost:5000/d12f8f87e157625eb71a401e9702945c"
#         },
#         {
#             "sample_name": "NA19428",
#             "sex": "male",
#             "biosample_id": "SAME124036",
#             "population_code": "LWK",
#             "population_name": "Luhya",
#             "superpopulation_code": "AFR",
#             "superpopulation_name": "African Ancestry",
#             "population_elastic_id": "LWK",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release,1000 Genomes phase 1 release",
#             "cram_drs_uri": "drs://localhost:5000/e2f80052614b061c8911d0554c6856c8",
#             "crai_drs_uri": "drs://localhost:5000/7ebc619232686aab4c4d7b523cd240b4",
#             "bundle_drs_uri": "drs://localhost:5000/f82380cb25f4efe8633a4697ae324a06"
#         },
#         {
#             "sample_name": "HG02577",
#             "sex": "female",
#             "biosample_id": "SAME1839642",
#             "population_code": "ACB",
#             "population_name": "African Caribbean",
#             "superpopulation_code": "AFR",
#             "superpopulation_name": "African Ancestry",
#             "population_elastic_id": "ACB",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release",
#             "cram_drs_uri": "drs://localhost:5000/159caf10d1d54939653c604e5804cb8c",
#             "crai_drs_uri": "drs://localhost:5000/6003aefac3b75e901bfb85372f1b1001",
#             "bundle_drs_uri": "drs://localhost:5000/c85316354303f38b5445723b59fdc5c8"
#         },
#         {
#             "sample_name": "NA19684",
#             "sex": "female",
#             "biosample_id": "SAME122941",
#             "population_code": "MXL",
#             "population_name": "Mexican Ancestry",
#             "superpopulation_code": "AMR",
#             "superpopulation_name": "American Ancestry",
#             "population_elastic_id": "MXL",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release,1000 Genomes phase 1 release",
#             "cram_drs_uri": "drs://localhost:5000/d1750dff64e9f46de96ea37875e6ea78",
#             "crai_drs_uri": "drs://localhost:5000/56b718061c6f65b308457dec76486b6b",
#             "bundle_drs_uri": "drs://localhost:5000/86836a203ed86ae6e87b5b6e263d19cb"
#         },
#         {
#             "sample_name": "NA19436",
#             "sex": "female",
#             "biosample_id": "SAME123852",
#             "population_code": "LWK",
#             "population_name": "Luhya",
#             "superpopulation_code": "AFR",
#             "superpopulation_name": "African Ancestry",
#             "population_elastic_id": "LWK",
#             "data_collections": "1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,1000 Genomes phase 3 release,1000 Genomes phase 1 release",
#             "cram_drs_uri": "drs://localhost:5000/b9c315034742b0282002ab7b976fdc9b",
#             "crai_drs_uri": "drs://localhost:5000/5422860b2645dd57c6047b433358e665",
#             "bundle_drs_uri": "drs://localhost:5000/1d9447407fdf953f5c20061d07055a3f"
#         }
#     ]
# }

# %% [markdown]
# ## 🔷 Search for data satisfying specific conditions
# **Search for samples with population_code = "PUR" and sex = "female"**

# %%
header = {"content-type":"application/json"}
request_body = {
  "query": "select sample_name , sex , population_code , population_name from one_thousand_genomes_sample where population_code=? and sex=?;",
  "parameters": [ "PUR", "female" ]
}
dc_search_resp = requests.post(dc_base_url+search_path, json = request_body, headers = header)
pretty_print_json(dc_search_resp)
# Out:
# {
#     "data": [
#         {
#             "sample_name": "HG00740",
#             "sex": "female",
#             "population_code": "PUR",
#             "population_name": "Puerto Rican"
#         },
#         {
#             "sample_name": "HG01070",
#             "sex": "female",
#             "population_code": "PUR",
#             "population_name": "Puerto Rican"
#         },
#         {
#             "sample_name": "HG01326",
#             "sex": "female",
#             "population_code": "PUR",
#             "population_name": "Puerto Rican"
#         }
#     ]
# }

# %% [markdown]
# ## 🔷 Exercise questions
# **Use the data from the sample One Thousand Genomes table above and refer to the search example above for the following questions. These questions will require some basic SQL knowledge.**
#
# **Tips:**
#
# **- Use "select" to choose which fields to display**\
# **- Use "from" to indicate the dataset you will be making the query to**\
# **- Use "where" to list the conditions of your query**\
# **- Data Connect queries should always end with ";"**

# %% [markdown]
# **Q1. Can you formulate a query to retrieve the cram_drs_uri and crai_drs_uri fields from one_thousand_genomes_sample table where population_name="Yoruba" and sex="male"?**

# %%
#Write your code here

# %% [markdown]
# **Q2. Can you formulate a query to retrieve the biosample_id and bundle_drs_uri fields from one_thousand_genomes_sample table where population_name="African Caribbean" and superpopulation_name="African Ancestry"?**

# %%
#Write your code here
