# %% [markdown]
# # Workflow Execution Service Endpoints
# Find the detailed GA4GH WES Specification [here](https://github.com/ga4gh/workflow-execution-service-schemas).

# %%
import requests
import json

wes_port = "6000"
ga4gh_base_url = "http://localhost:{}/ga4gh/{}/v1"
wes_base_url = ga4gh_base_url.format(wes_port,"wes")

service_info_path = "/service-info"
runs_path = "/runs"

def pretty_print_json(response):
    # pretty print JSON in blue color
    print("\033[38;2;8;75;138m"+json.dumps(response.json(), indent=4)+"\033[0m")
    
def print_head(text):
    # print in green color
    print("\033[38;2;8;138;75m"+text+"\033[0m")

# %% [markdown]
# ## i. Get `/service-info`
# **Retrieve information about this service**

# %%
http_method = "GET"
request_url = wes_base_url+service_info_path

print_head("{} request to {}".format(http_method, request_url))

# GET request to service-info endpoint
wes_service_info_resp = requests.request(http_method, request_url)

# print the response
pretty_print_json(wes_service_info_resp)
# Out:
# GET request to http://localhost:6000/ga4gh/wes/v1/service-info
# {
#     "id": "wes.starterkit.federatedgenomics.org",
#     "name": "Federated Genomics WES service",
#     "description": "Workflow Execution Service (WES) instance. Enables small-scale test workflows to be run over the web. Deployment of the GA4GH Starter Kit.",
#     "contactUrl": "mailto:nobody@federatedgenomics.org",
#     "documentationUrl": "https://apidocs.federatedgenomics.org/wes",
#     "createdAt": "2022-07-10T09:00:00Z",
#     "updatedAt": "2022-07-10T09:00:00Z",
#     "environment": "development",
#     "version": "1.0.0",
#     "type": {
#         "group": "org.ga4gh",
#         "artifact": "wes",
#         "version": "1.0.1"
#     },
#     "organization": {
#         "name": "Federated Genomics",
#         "url": "https://this-is-not-a-site.federatedgenomics.org"
#     },
#     "workflow_type_versions": {
#         "WDL": [
#             "1.0"
#         ],
#         "NEXTFLOW": [
#             "21.04.0"
#         ]
#     },
#     "workflow_engine_versions": {
#         "NATIVE": "1.0.0"
#     }
# }

# %% [markdown]
# ## ii. List `/runs`
# **Retrieves the list of runs**

# %%
http_method = "GET"
request_url = wes_base_url+runs_path

print_head("{} request to {}".format(http_method, request_url))

# GET request to /runs endpoint
wes_list_runs_resp = requests.request(http_method, request_url)

# print the response
pretty_print_json(wes_list_runs_resp)
# Out:
# GET request to http://localhost:6000/ga4gh/wes/v1/runs
# {
#     "runs": [
#         {
#             "run_id": "1f58bf54-8207-491c-b2fe-46ee9a68fcad",
#             "state": "COMPLETE"
#         },
#         {
#             "run_id": "9df0e030-c8fc-45df-b230-77d818153874",
#             "state": "COMPLETE"
#         },
#         {
#             "run_id": "16a350a4-f689-4cd7-b633-d01735f96e4f",
#             "state": "COMPLETE"
#         }
#     ]
# }

# %% [markdown]
# ## iii. Post a Nextflow workflow
# **Run `samtools head` on this file: `https://ga4gh-ismb-tutorial-2022.s3.us-east-2.amazonaws.com/data/1000genomes/cram/lowcov/HG00118.lowcoverage.downsampled.cram`**

# %%
http_method = "POST"
request_url = wes_base_url + runs_path

nextflow_workflow_url = "https://github.com/ga4gh/samtools-head-nf"
input_file = "https://ga4gh-ismb-tutorial-2022.s3.us-east-2.amazonaws.com/data/1000genomes/cram/lowcov/HG00118.lowcoverage.downsampled.cram"

data = {
    'workflow_type': 'NEXTFLOW',
    'workflow_type_version': '21.04.0',
    'workflow_url': nextflow_workflow_url,
    'workflow_params': f'{{"input":"{input_file}"}}'
}

print_head("{} request to {}".format(http_method, request_url))

# Post a Nextflow workflow
wes_post_workflow_response = requests.request(http_method, request_url, data = data)

# print the response
pretty_print_json(wes_post_workflow_response)

current_run_id = wes_post_workflow_response.json()["run_id"]

print_head("run_id = {}".format(current_run_id))
# Out:
# POST request to http://localhost:6000/ga4gh/wes/v1/runs
# {
#     "run_id": "65c62b84-125d-4493-b996-81e7404309bd"
# }
# run_id = 65c62b84-125d-4493-b996-81e7404309bd

# %% [markdown]
# ### iii a. Monitor the run

# %%
http_method = "GET"
request_url = wes_base_url + runs_path + "/" + current_run_id

print_head("{} request to {}".format(http_method, request_url))

# Get request to /runs/{run_id}
monitor_run_response = requests.request(http_method, request_url)

# print the response
pretty_print_json(monitor_run_response)
# Out:
# GET request to http://localhost:6000/ga4gh/wes/v1/runs/65c62b84-125d-4493-b996-81e7404309bd
# {
#     "run_id": "65c62b84-125d-4493-b996-81e7404309bd",
#     "request": {
#         "workflow_params": {
#             "input": "https://ga4gh-ismb-tutorial-2022.s3.us-east-2.amazonaws.com/data/1000genomes/cram/lowcov/HG00118.lowcoverage.downsampled.cram"
#         },
#         "workflow_type": "NEXTFLOW",
#         "workflow_type_version": "21.04.0",
#         "workflow_url": "https://github.com/ga4gh/samtools-head-nf"
#     },
#     "state": "RUNNING",
#     "run_log": {
#         "name": "ga4gh/samtools-head-nf",
#         "cmd": [
#             "#!/bin/bash -ue",
#             "samtools head https://ga4gh-ismb-tutorial-2022.s3.us-east-2.amazonaws.com/data/1000genomes/cram/lowcov/HG00118.lowcoverage.downsampled.cram > output_samtools_head.txt"
#         ],
#         "start_time": "2025-04-24T13:53:56Z",
#         "end_time": "2025-04-24T13:53:57Z",
#         "stdout": "http://localhost:6000/ga4gh/wes/v1/logs/nextflow/stdout/65c62b84-125d-4493-b996-81e7404309bd?workdirs=81%2F03bbc89cec7ab30f8400bd57e369a8",
#         "stderr": "http://localhost:6000/ga4gh/wes/v1/logs/nextflow/stderr/65c62b84-125d-4493-b996-81e7404309bd?workdirs=81%2F03bbc89cec7ab30f8400bd57e369a8",
#         "exit_code": 0
#     },
#     "task_logs": [
#         {
#             "name": "samtools_head",
#             "cmd": [
#                 "#!/bin/bash -ue",
#                 "samtools head https://ga4gh-ismb-tutorial-2022.s3.us-east-2.amazonaws.com/data/1000genomes/cram/lowcov/HG00118.lowcoverage.downsampled.cram > output_samtools_head.txt"
#             ],
#             "start_time": "2025-04-24T13:53:56Z",
#             "end_time": "2025-04-24T13:53:57Z",
#             "stdout": "http://localhost:6000/ga4gh/wes/v1/logs/nextflow/stdout/65c62b84-125d-4493-b996-81e7404309bd/81/03bbc89cec7ab30f8400bd57e369a8",
#             "stderr": "http://localhost:6000/ga4gh/wes/v1/logs/nextflow/stderr/65c62b84-125d-4493-b996-81e7404309bd/81/03bbc89cec7ab30f8400bd57e369a8",
#             "exit_code": 0
#         }
#     ],
#     "outputs": {
#         "output_samtools_head.txt": "file:///tmp/shared/wes/wes_runs/65/c6/2b/65c62b84-125d-4493-b996-81e7404309bd/work/81/03bbc89cec7ab30f8400bd57e369a8/output_samtools_head.txt"
#     }
# }

# %% [markdown]
# ## iv. Post a Nextflow workflow
# **Run `samtools head` on the drs_object with DRS URI `drs://localhost:5000/8e18bfb64168994489bc9e7fda0acd4f`**

# %%
http_method = "POST"
request_url = wes_base_url+runs_path

nextflow_workflow_url = "https://github.com/ga4gh/samtools-head-nf"
input_file = "drs://localhost:4500/77b0f3d65271c4a0064ff7760828dd92"

data = {
    'workflow_type': 'NEXTFLOW',
    'workflow_type_version': '21.04.0',
    'workflow_url': nextflow_workflow_url,
    'workflow_params': f'{{"input":"{input_file}"}}'
}

# Post a Nextflow workflow
wes_post_workflow_response = requests.request(http_method, request_url, data = data)

# print the response
pretty_print_json(wes_post_workflow_response)

current_run_id = wes_post_workflow_response.json()["run_id"]

print_head("run_id = {}".format(current_run_id))
# Out:
# {'workflow_params': '{"input":"drs://localhost:4500/77b0f3d65271c4a0064ff7760828dd92"}',
#  'workflow_type': 'NEXTFLOW',
#  'workflow_type_version': '21.04.0',
#  'workflow_url': 'https://github.com/ga4gh/samtools-head-nf'}
# {
#     "run_id": "b4c3f757-6709-4f1d-99bf-841162461ed7"
# }
# run_id = b4c3f757-6709-4f1d-99bf-841162461ed7

# %% [markdown]
# ### iv a. Monitor the run

# %%
http_method = "GET"
request_url = wes_base_url + runs_path + "/" + current_run_id

print_head("{} request to {}".format(http_method, request_url))

# Get request to /runs/{run_id}
monitor_run_response = requests.request(http_method, request_url)

# print the response
pretty_print_json(monitor_run_response)
# Out:
# GET request to http://localhost:6000/ga4gh/wes/v1/runs/b4c3f757-6709-4f1d-99bf-841162461ed7
# {
#     "run_id": "b4c3f757-6709-4f1d-99bf-841162461ed7",
#     "request": {
#         "workflow_params": {
#             "input": "drs://localhost:4500/77b0f3d65271c4a0064ff7760828dd92"
#         },
#         "workflow_type": "NEXTFLOW",
#         "workflow_type_version": "21.04.0",
#         "workflow_url": "https://github.com/ga4gh/samtools-head-nf"
#     },
#     "state": "COMPLETE",
#     "run_log": {
#         "name": "ga4gh/samtools-head-nf",
#         "cmd": [
#             "#!/bin/bash -ue",
#             "samtools head https://s3.us-east-2.amazonaws.com/ga4gh-ismb-tutorial-2022/data/1000genomes/cram/highcov/NA12842.final.2400kb.cram > output_samtools_head.txt"
#         ],
#         "start_time": "2025-04-24T14:04:03Z",
#         "end_time": "2025-04-24T14:04:05Z",
#         "stdout": "http://localhost:6000/ga4gh/wes/v1/logs/nextflow/stdout/b4c3f757-6709-4f1d-99bf-841162461ed7?workdirs=d6%2F5c4608aa1e6da43263d0cb2e937f03",
#         "stderr": "http://localhost:6000/ga4gh/wes/v1/logs/nextflow/stderr/b4c3f757-6709-4f1d-99bf-841162461ed7?workdirs=d6%2F5c4608aa1e6da43263d0cb2e937f03",
#         "exit_code": 0
#     },
#     "task_logs": [
#         {
#             "name": "samtools_head",
#             "cmd": [
#                 "#!/bin/bash -ue",
#                 "samtools head https://s3.us-east-2.amazonaws.com/ga4gh-ismb-tutorial-2022/data/1000genomes/cram/highcov/NA12842.final.2400kb.cram > output_samtools_head.txt"
#             ],
#             "start_time": "2025-04-24T14:04:03Z",
#             "end_time": "2025-04-24T14:04:05Z",
#             "stdout": "http://localhost:6000/ga4gh/wes/v1/logs/nextflow/stdout/b4c3f757-6709-4f1d-99bf-841162461ed7/d6/5c4608aa1e6da43263d0cb2e937f03",
#             "stderr": "http://localhost:6000/ga4gh/wes/v1/logs/nextflow/stderr/b4c3f757-6709-4f1d-99bf-841162461ed7/d6/5c4608aa1e6da43263d0cb2e937f03",
#             "exit_code": 0
#         }
#     ],
#     "outputs": {
#         "output_samtools_head.txt": "file:///tmp/shared/wes/wes_runs/b4/c3/f7/b4c3f757-6709-4f1d-99bf-841162461ed7/work/d6/5c4608aa1e6da43263d0cb2e937f03/output_samtools_head.txt"
#     }
# }

# %% [markdown]
# ## For more endpoints, find the detailed GA4GH WES Specification [here](https://github.com/ga4gh/workflow-execution-service-schemas).
